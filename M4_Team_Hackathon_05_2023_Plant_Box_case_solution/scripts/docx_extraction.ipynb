# %%
# !pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 43.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184491 sha256=6a5503753e2b14e0bf8675df2d4d84bbbf85f2551889b05ccef9ff1d48baba2c
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built python-docx
# ...

# %%
import pandas as pd
from docx import Document
import pprint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Projects/Plant_box
# Out:
# /content/drive/MyDrive/Projects/Plant_box

# %%
# !ls
# Out:
# scripts  train_dataset	work_directory

# %%
# %%time
document = Document('train_dataset/Атлас_2021.docx')
# Out:
# CPU times: user 14 s, sys: 11.6 s, total: 25.7 s
# Wall time: 28.6 s

# %%
pprint.pprint(document)

# %%
doc = pd.DataFrame(document)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-35ec93ea8264> in <cell line: 1>()
# ----> 1 doc = pd.DataFrame(document)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     779         else:
#     780             if index is None or columns is None:
# --> 781                 raise ValueError("DataFrame constructor not properly called!")
#     782
#     783             index = ensure_index(index)
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.read_csv('work_directory/region_herb.csv')

# %%
df
# Out:
#                                  Растение\tРегион
# 0           аир обыкновенный\tРеспублика Марий Эл
# 1               аир обыкновенный\tРеспублика Тыва
# 2             аир обыкновенный\tТюменская область
# 3             аралия высокая\tСахалинская область
# 4    алтей лекарственный\tРеспублика Башкортостан
# ..                                            ...
# 301        щитовник мужской\tОренбургская область
# 302          щитовник мужской\tРостовская область
# 303         щитовник мужской\tСаратовская область
# 304             щитовник мужской\tРеспублика Тыва
# 305           щитовник мужской\tТюменская область
#
# [306 rows x 1 columns]

# %%
df.loc
