# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive/MyDrive/Projects/Plant_box/work_directory

# %%
ls

# %%
df = pd.read_parquet('merged_df.parquet')

# %%
df[['Название.', 'Фармакологические свойства.', 'Применение в медицине.', 'Регион']]
