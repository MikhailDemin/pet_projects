# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=803d949c1301eb7515d95a1c06382885ee2ee394d423448451cbf228e05ccb9a
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup

def get_regions(url):
  # URL страницы для парсинга
  # Отправка GET-запроса и получение содержимого страницы
  response = requests.get(url)
  content = response.content

  # Создание объекта BeautifulSoup для парсинга страницы
  soup = BeautifulSoup(content, 'html.parser')

  # Нахождение всех элементов с тегом "row-lined row-state-normal"
  elements = soup.find_all(class_='row-lined row-state-normal')

  regioin_dict = {}
  # Перебор найденных элементов
  for element in elements:
      # Нахождение тегов "a" внутри текущего элемента
      a_tag = element.find('a')
      regioin_dict[a_tag.get_text()] =  'https://www.plantarium.ru/' + a_tag['href']

  return regioin_dict

def get_list_of_herbs(url):
  # Отправляем GET-запрос и получаем HTML-страницу
  response = requests.get(url)
  html = response.text

  # Создаем объект BeautifulSoup для парсинга HTML
  soup = BeautifulSoup(html, "html.parser")

  # Ищем элементы с тегом "row-state-normal" и "row-lined"
  elements = soup.find_all(class_="row-state-normal row-lined")

  # Перебираем найденные элементы и выводим текст
  list_of_herbs = []
  for element in elements:
      tds = element.find_all('td')
      # print(tds[3].get_text().split(','))
      for i in tds[3].get_text().split(','):
        # print(i.strip())
        list_of_herbs.append(i.strip().lower())
      # for td in tds:
      #   print(td.get_text())
      # text = element.get_text()
      # print(text)
  return list_of_herbs

# %%
#загружаем в словарь списки растений по регионам и записываем в area_herb: ключ наименование округа, значение - список растений
area_herb = {}
region_dict = get_regions('https://www.plantarium.ru/page/redbooks.html')
#список регионов из справочника. обратить вниамние, что наименования официальные могут не совпадать с наименованиями в списке красной книги
my_file = open("regions.txt", "r", encoding = 'utf8')
regions_list = my_file.readlines()
regions_list = [word.strip() for word in regions_list]
my_file.close()
for region in get_regions('https://www.plantarium.ru/page/redbooks.html'):
  if region in regions_list:
    print(region + " в списке")
    area_herb[region] = get_list_of_herbs(region_dict[region])
  else:
    print(region + " отсутствует в списке")
# Out:
# Республика Адыгея отсутствует в списке
# Азербайджанская Республика отсутствует в списке
# Республика Алтай в списке
# Алтайский край в списке
# Амурская область в списке
# Республика Армения отсутствует в списке
# Архангельская область в списке
# Астраханская область в списке
# Балтийский регион отсутствует в списке
# Республика Башкортостан в списке
# Республика Беларусь отсутствует в списке
# Белгородская область в списке
# Республика Болгария отсутствует в списке
# Брянская область в списке
# Республика Бурятия в списке
# Бурятская АССР отсутствует в списке
# Владимирская область в списке
# Волгоградская область в списке
# Вологодская область в списке
# Воронежская область в списке
# Восточная Фенноскандия отсутствует в списке
# Грузинская ССР отсутствует в списке
# Республика Дагестан в списке
# Донецкая Народная Республика в списке
# Еврейская автономная область в списке
# Забайкальский край в списке
# Ивановская область отсутствует в списке
# Республика Ингушетия в списке
# Иркутская область в списке
# Кабардино-Балкарская Республика в списке
# Казахская ССР отсутствует в списке
# Республика Казахстан отсутствует в списке
# Калининградская область в списке
# Республика Калмыкия в списке
# Калужская область в списке
# Камчатский край в списке
# Карачаево-Черкесская Республика в списке
# Республика Карелия в списке
# Кемеровская область отсутствует в списке
# Киргизская республика отсутствует в списке
# Кировская область в списке
# Республика Коми в списке
# Костромская область в списке
# Краснодарский край в списке
# Красноярский край в списке
# Республика Крым в списке
# Курганская область в списке
# Курская область в списке
# Латвийская Республика отсутствует в списке
# Ленинградская область в списке
# Липецкая область в списке
# Литовская Республика отсутствует в списке
# Луганская Народная Республика в списке
# Магаданская область в списке
# Республика Марий Эл в списке
# Республика Молдова отсутствует в списке
# Республика Мордовия в списке
# Город Москва отсутствует в списке
# Московская область в списке
# Мурманская область в списке
# Ненецкий автономный округ в списке
# Нижегородская область в списке
# Новгородская область в списке
# Новосибирская область в списке
# Омская область в списке
# Оренбургская область в списке
# Орловская область в списке
# Пензенская область в списке
# Пермская область отсутствует в списке
# Пермский край в списке
# Приднестровская Молдавская Республика отсутствует в списке
# Приморский край в списке
# Псковская область в списке
# Российская Федерация отсутствует в списке
# Российская Советская Федеративная Социалистическая Республика отсутствует в списке
# Ростовская область в списке
# Рязанская область в списке
# Самарская область в списке
# Город Санкт-Петербург отсутствует в списке
# Саратовская область в списке
# Республика Саха (Якутия) в списке
# Сахалинская область в списке
# Свердловская область в списке
# Город Севастополь отсутствует в списке
# Республика Северная Осетия — Алания в списке
# Смоленская область в списке
# СССР отсутствует в списке
# Ставропольский край в списке
# Республика Таджикистан отсутствует в списке
# Таджикская ССР отсутствует в списке
# Тамбовская область в списке
# Республика Татарстан отсутствует в списке
# Тверская область в списке
# Томская область в списке
# Тульская область в списке
# Туркменистан отсутствует в списке
# Туркменистан Республика отсутствует в списке
# Республика Тыва в списке
# Тюменская область в списке
# Удмуртская республика отсутствует в списке
# Узбекистан отсутствует в списке
# Республика Узбекистан отсутствует в списке
# Украина отсутствует в списке
# Украина, Винницкая область отсутствует в списке
# Украина, Волынская область отсутствует в списке
# Украина, Днепропетровская область отсутствует в списке
# Украина, Донецкая область отсутствует в списке
# Украина, Житомирская область отсутствует в списке
# Украина, Закарпатская область отсутствует в списке
# Украина, Запорожская область отсутствует в списке
# Украина, Ивано-Франковская область отсутствует в списке
# Украина, Киев отсутствует в списке
# Украина, Киевская область отсутствует в списке
# Украина, Кировоградская область отсутствует в списке
# Украина, Луганская область отсутствует в списке
# Украина, Львовская область отсутствует в списке
# Украина, Николаевская область отсутствует в списке
# Украина, Одесская область отсутствует в списке
# Украина, Полтавская область отсутствует в списке
# Украина, Ровенская область отсутствует в списке
# Украина, Сумская область отсутствует в списке
# Украина, Тернопольская область отсутствует в списке
# Украина, Харьковская область отсутствует в списке
# Украина, Херсонская область отсутствует в списке
# Украина, Хмельницкая область отсутствует в списке
# Украина, Черниговская область отсутствует в списке
# Украина, Черновицкая область отсутствует в списке
# Ульяновская область в списке
# Усть-Ордынский Бурятский автономный округ отсутствует в списке
# Финляндия отсутствует в списке
# Хабаровский край в списке
# Республика Хакасия в списке
# Ханты-Мансийский автономный округ отсутствует в списке
# Челябинская область в списке
# Чеченская Республика в списке
# Читинская область отсутствует в списке
# Чувашская республика отсутствует в списке
# Чукотский автономный округ в списке
# Эстонская Республика отсутствует в списке
# Республика Южная Осетия отсутствует в списке
# Ямало-Ненецкий автономный округ в списке
# Ярославская область в списке

# %%
# #Собираем по регионам все растения и сохраняем в файл
# for ind, reg in enumerate(get_regions('https://www.plantarium.ru/page/redbooks.html')):
#   print(reg, region_dict[reg], ind)

#   with open(f"regions/{reg}.txt", 'w', encoding='utf-8' ) as f:
#     lines = get_list_of_herbs(region_dict[reg])
#     for line in lines:
#       f.write(f"{line}\n")

# %%
#Загружаем список растений для сравнения
file = open("plants.txt", "r", encoding = 'utf8')
my_herbs_list = file.readlines()
my_herbs_list = [word.strip().lower() for word in my_herbs_list]
file.close()
# Проверяем наличие растений в списке каждого региона
print(my_herbs_list)
# Out:
# ['аденостилес ромболистный', 'аир обыкновенный', 'аралия высокая', 'алоэ древовидное', 'алтей лекарственный', 'амми большая', 'амми зубная', 'баранец обыкновенный', 'анис обыкновенный', 'катарантус розовый', 'крапива двудомная', 'апонтикум сафлоровидный', 'цетрария исландская', 'арника горная', 'арника шамиссо', 'арония черноплодная', 'красавка обыкновенная', 'бадан толстолистный', 'барбарис обыкновенный', 'барвинок малый', 'бархат амурский', 'белена черная', 'белокопытник гибридный', 'бессмертник песчаный', 'кровохлёбка лекарственная', 'борец северный', 'бриофиллум перистый', 'брусника обыкновенная', 'бузина черная', 'валериана лекарственная', 'василек благословенный', 'василек посевной', 'вербена лекарственная', 'вздутоплодник сибирский', 'виногр адолистный', 'володушка золотистая', 'гамамелис виргинский', 'горец змеиный', 'горец перечный', 'горец почечуйный', 'горец птичий', 'горицвет весенний', 'девясил высокий', 'десмодиум канадский', 'диоскорея ниппонская', 'донник лекарственный', 'дуб обыкновенный', 'дурман обыкновенный', 'дурнишник обыкновенный', 'душица обыкновенная', 'ель обыкновенная', 'жостер слабительный', 'заманиха высокая', 'зверобой продырявленный', 'земляника лесная', 'змееголовник молдавский', 'золототысячник обыкновенный', 'истод тонколистный', 'калина обыкновенная', 'каштан обыкновенный', 'копеечник альпийский', 'копытень европейский', 'кориандр посевной', 'коровяк густоцветковый', 'крушина ольховидная', 'кукуруза обыкновенная', 'лабазник вязолистный', 'лабазник обыкновенный', 'ламинария японская', 'ландыш кейске', 'лапчатка белая', 'лапчатка прямостоячая', 'лапчатка серебристая', 'леспедеца двуцветная', 'леспедеца копеечниковая', 'лопух большой', 'магнолия крупноцветковая', 'маклея сердцевидная', 'малина обыкновенная', 'мелисса лекарственная', 'миндаль обыкновенный', 'можжевельник обыкновенный', 'морковь дикая', 'черёмуха обыкновенная', 'мята перечная', 'наперстянка крупноцветковая', 'облепиха крушиновидная', 'овес посевной', 'одуванчик изогнутый', 'ортосифон остистый', 'очиток большой', 'пажитник сенной', 'пальчатый тангутский', 'пастернак посевной', 'переступень белый', 'перец однолетний', 'подорожник блошный', 'подорожник большой', 'подофилл щитовидный', 'полынь обыкновенная', 'прутняк обыкновенный', 'репешок волосистый', 'репешок обыкновенный', 'ромашка аптечная', 'ромашка безъязычковая', 'рябина обыкновенная', 'сабельник болотный', 'свободноягодник колючий', 'секуринега полукустарниковая', 'серпуха венценосная', 'синюха голубая', 'скополия карниолийская', 'скумпия кожевенная', 'смоковница обыкновенная', 'смородина черная', 'солодка голая', 'спорынья пурпуровая', 'стальник колючий', 'сумах дубильный', 'сумка обыкновенная', 'термопсис ланцетовидный', 'тимьян обыкновенный', 'тимьян ползучий', 'тмин обыкновенный', 'толокнянка обыкновенная', 'тыква обыкновенная', 'тысячелистник обыкновенный', 'укроп пахучий', 'фасоль обыкновенная', 'хвощ полевой', 'хмель обыкновенный', 'цикорий обыкновенный', 'цинер ариелистный', 'чемерица лобеля', 'черника обыкновенная', 'чернушка дамасская', 'мать-и-мачеха обыкновенная', 'чистотел большой', 'шиповник майский', 'шлемник байкальский', 'щавель конский', 'щитовник мужской', 'эвкалипт прутовидный', 'эвкоммия вязолистная', 'эрва шерстистая']

# %%
import csv

with open("region_herb.csv", mode="w", encoding='utf-8') as w_file:
    file_writer = csv.writer(w_file, delimiter = "\t")
    file_writer.writerow(["Растение", "Регион"])
    #сравниваем список растений из файла со списком в словаре
    for herb in my_herbs_list:
        for reg in area_herb: 
          if herb in area_herb[reg]:
            print(herb + ", " + reg )
            file_writer.writerow([herb, reg])
# Out:
# аир обыкновенный, Республика Марий Эл
# аир обыкновенный, Республика Тыва
# аир обыкновенный, Тюменская область
# аралия высокая, Сахалинская область
# алтей лекарственный, Республика Башкортостан
# алтей лекарственный, Брянская область
# алтей лекарственный, Республика Калмыкия
# алтей лекарственный, Курганская область
# алтей лекарственный, Курская область
# алтей лекарственный, Липецкая область
# алтей лекарственный, Омская область
# алтей лекарственный, Пензенская область
# алтей лекарственный, Тамбовская область
# алтей лекарственный, Ульяновская область
# баранец обыкновенный, Республика Башкортостан
# баранец обыкновенный, Брянская область
# баранец обыкновенный, Владимирская область
# баранец обыкновенный, Вологодская область
# баранец обыкновенный, Республика Ингушетия
# баранец обыкновенный, Калужская область
# баранец обыкновенный, Костромская область
# баранец обыкновенный, Курганская область
# баранец обыкновенный, Курская область
# баранец обыкновенный, Республика Мордовия
# баранец обыкновенный, Московская область
# баранец обыкновенный, Нижегородская область
# баранец обыкновенный, Новосибирская область
# баранец обыкновенный, Пензенская область
# баранец обыкновенный, Рязанская область
# баранец обыкновенный, Смоленская область
# баранец обыкновенный, Ставропольский край
# баранец обыкновенный, Тверская область
# баранец обыкновенный, Тульская область
# баранец обыкновенный, Тюменская область
# баранец обыкновенный, Ярославская область
# цетрария исландская, Брянская область
# цетрария исландская, Воронежская область
# цетрария исландская, Курская область
# цетрария исландская, Липецкая область
# цетрария исландская, Пензенская область
# цетрария исландская, Тамбовская область
# красавка обыкновенная, Карачаево-Черкесская Республика
# красавка обыкновенная, Республика Крым
# бадан толстолистный, Республика Саха (Якутия)
# барбарис обыкновенный, Брянская область
# барбарис обыкновенный, Чеченская Республика
# бархат амурский, Амурская область
# бессмертник песчаный, Республика Башкортостан
# бессмертник песчаный, Владимирская область
# бессмертник песчаный, Вологодская область
# бессмертник песчаный, Кировская область
# бессмертник песчаный, Костромская область
# бессмертник песчаный, Краснодарский край
# бессмертник песчаный, Красноярский край
# бессмертник песчаный, Ленинградская область
# бессмертник песчаный, Республика Марий Эл
# бессмертник песчаный, Нижегородская область
# бессмертник песчаный, Новгородская область
# бессмертник песчаный, Самарская область
# бессмертник песчаный, Тверская область
# бессмертник песчаный, Тульская область
# бессмертник песчаный, Тюменская область
# бессмертник песчаный, Чеченская Республика
# кровохлёбка лекарственная, Вологодская область
# кровохлёбка лекарственная, Костромская область
# кровохлёбка лекарственная, Новгородская область
# борец северный, Брянская область
# борец северный, Калужская область
# борец северный, Мурманская область
# борец северный, Самарская область
# борец северный, Саратовская область
# борец северный, Тульская область
# борец северный, Ульяновская область
# брусника обыкновенная, Воронежская область
# брусника обыкновенная, Кабардино-Балкарская Республика
# брусника обыкновенная, Курская область
# брусника обыкновенная, Липецкая область
# брусника обыкновенная, Самарская область
# брусника обыкновенная, Саратовская область
# валериана лекарственная, Кабардино-Балкарская Республика
# валериана лекарственная, Чеченская Республика
# вздутоплодник сибирский, Амурская область
# вздутоплодник сибирский, Забайкальский край
# вздутоплодник сибирский, Красноярский край
# вздутоплодник сибирский, Республика Саха (Якутия)
# володушка золотистая, Курганская область
# володушка золотистая, Республика Мордовия
# володушка золотистая, Оренбургская область
# володушка золотистая, Пензенская область
# володушка золотистая, Самарская область
# володушка золотистая, Ульяновская область
# горец змеиный, Курганская область
# горец змеиный, Псковская область
# горец змеиный, Самарская область
# горец змеиный, Саратовская область
# горицвет весенний, Республика Алтай
# горицвет весенний, Белгородская область
# горицвет весенний, Брянская область
# горицвет весенний, Волгоградская область
# горицвет весенний, Воронежская область
# горицвет весенний, Донецкая Народная Республика
# горицвет весенний, Карачаево-Черкесская Республика
# горицвет весенний, Кировская область
# горицвет весенний, Краснодарский край
# горицвет весенний, Красноярский край
# горицвет весенний, Республика Крым
# горицвет весенний, Курская область
# горицвет весенний, Липецкая область
# горицвет весенний, Луганская Народная Республика
# горицвет весенний, Республика Мордовия
# горицвет весенний, Московская область
# горицвет весенний, Нижегородская область
# горицвет весенний, Оренбургская область
# горицвет весенний, Орловская область
# горицвет весенний, Пензенская область
# горицвет весенний, Пермский край
# горицвет весенний, Ростовская область
# горицвет весенний, Рязанская область
# горицвет весенний, Самарская область
# горицвет весенний, Саратовская область
# горицвет весенний, Свердловская область
# горицвет весенний, Республика Северная Осетия — Алания
# горицвет весенний, Ставропольский край
# горицвет весенний, Тамбовская область
# горицвет весенний, Тульская область
# горицвет весенний, Ульяновская область
# горицвет весенний, Республика Хакасия
# девясил высокий, Республика Калмыкия
# девясил высокий, Новосибирская область
# девясил высокий, Рязанская область
# диоскорея ниппонская, Амурская область
# диоскорея ниппонская, Еврейская автономная область
# диоскорея ниппонская, Хабаровский край
# дуб обыкновенный, Вологодская область
# душица обыкновенная, Республика Калмыкия
# жостер слабительный, Калужская область
# жостер слабительный, Новгородская область
# жостер слабительный, Смоленская область
# жостер слабительный, Тверская область
# заманиха высокая, Приморский край
# золототысячник обыкновенный, Вологодская область
# золототысячник обыкновенный, Костромская область
# золототысячник обыкновенный, Ленинградская область
# золототысячник обыкновенный, Новгородская область
# золототысячник обыкновенный, Тамбовская область
# золототысячник обыкновенный, Ярославская область
# копеечник альпийский, Вологодская область
# копеечник альпийский, Еврейская автономная область
# копеечник альпийский, Республика Коми
# копеечник альпийский, Мурманская область
# копеечник альпийский, Томская область
# копытень европейский, Республика Алтай
# копытень европейский, Алтайский край
# копытень европейский, Донецкая Народная Республика
# копытень европейский, Республика Карелия
# копытень европейский, Новосибирская область
# копытень европейский, Оренбургская область
# копытень европейский, Ростовская область
# копытень европейский, Тюменская область
# коровяк густоцветковый, Калужская область
# коровяк густоцветковый, Саратовская область
# крушина ольховидная, Мурманская область
# лабазник обыкновенный, Кировская область
# лабазник обыкновенный, Красноярский край
# лабазник обыкновенный, Ленинградская область
# лабазник обыкновенный, Новгородская область
# лабазник обыкновенный, Псковская область
# ландыш кейске, Забайкальский край
# лапчатка белая, Белгородская область
# лапчатка белая, Воронежская область
# лапчатка белая, Калужская область
# лапчатка белая, Липецкая область
# лапчатка белая, Московская область
# лапчатка белая, Пензенская область
# лапчатка белая, Саратовская область
# лапчатка белая, Смоленская область
# лапчатка белая, Тамбовская область
# лапчатка белая, Ульяновская область
# лапчатка прямостоячая, Донецкая Народная Республика
# лапчатка прямостоячая, Республика Коми
# лапчатка прямостоячая, Омская область
# лапчатка прямостоячая, Самарская область
# лапчатка прямостоячая, Томская область
# леспедеца двуцветная, Забайкальский край
# можжевельник обыкновенный, Брянская область
# можжевельник обыкновенный, Воронежская область
# можжевельник обыкновенный, Липецкая область
# можжевельник обыкновенный, Республика Мордовия
# можжевельник обыкновенный, Пензенская область
# можжевельник обыкновенный, Тамбовская область
# можжевельник обыкновенный, Тульская область
# можжевельник обыкновенный, Ульяновская область
# морковь дикая, Республика Марий Эл
# наперстянка крупноцветковая, Алтайский край
# наперстянка крупноцветковая, Брянская область
# наперстянка крупноцветковая, Кировская область
# наперстянка крупноцветковая, Курганская область
# наперстянка крупноцветковая, Курская область
# наперстянка крупноцветковая, Республика Мордовия
# наперстянка крупноцветковая, Новосибирская область
# наперстянка крупноцветковая, Оренбургская область
# наперстянка крупноцветковая, Орловская область
# наперстянка крупноцветковая, Пензенская область
# наперстянка крупноцветковая, Псковская область
# наперстянка крупноцветковая, Самарская область
# наперстянка крупноцветковая, Свердловская область
# наперстянка крупноцветковая, Смоленская область
# наперстянка крупноцветковая, Тверская область
# наперстянка крупноцветковая, Тюменская область
# наперстянка крупноцветковая, Ульяновская область
# облепиха крушиновидная, Чеченская Республика
# очиток большой, Вологодская область
# очиток большой, Костромская область
# переступень белый, Астраханская область
# подорожник большой, Пензенская область
# подорожник большой, Самарская область
# подорожник большой, Тамбовская область
# подорожник большой, Ульяновская область
# прутняк обыкновенный, Краснодарский край
# прутняк обыкновенный, Республика Крым
# репешок волосистый, Вологодская область
# репешок обыкновенный, Вологодская область
# сабельник болотный, Белгородская область
# сабельник болотный, Донецкая Народная Республика
# сабельник болотный, Карачаево-Черкесская Республика
# сабельник болотный, Краснодарский край
# сабельник болотный, Самарская область
# сабельник болотный, Саратовская область
# свободноягодник колючий, Амурская область
# секуринега полукустарниковая, Еврейская автономная область
# секуринега полукустарниковая, Забайкальский край
# серпуха венценосная, Донецкая Народная Республика
# серпуха венценосная, Калужская область
# серпуха венценосная, Кировская область
# серпуха венценосная, Республика Марий Эл
# серпуха венценосная, Московская область
# серпуха венценосная, Рязанская область
# серпуха венценосная, Тамбовская область
# синюха голубая, Воронежская область
# синюха голубая, Самарская область
# синюха голубая, Саратовская область
# скумпия кожевенная, Чеченская Республика
# смоковница обыкновенная, Республика Дагестан
# смоковница обыкновенная, Краснодарский край
# солодка голая, Донецкая Народная Республика
# солодка голая, Республика Крым
# солодка голая, Курганская область
# солодка голая, Самарская область
# стальник колючий, Республика Башкортостан
# стальник колючий, Ленинградская область
# стальник колючий, Смоленская область
# стальник колючий, Тверская область
# стальник колючий, Ульяновская область
# сумах дубильный, Карачаево-Черкесская Республика
# тимьян ползучий, Владимирская область
# тимьян ползучий, Калужская область
# тимьян ползучий, Московская область
# тимьян ползучий, Мурманская область
# тимьян ползучий, Нижегородская область
# толокнянка обыкновенная, Брянская область
# толокнянка обыкновенная, Владимирская область
# толокнянка обыкновенная, Калининградская область
# толокнянка обыкновенная, Калужская область
# толокнянка обыкновенная, Карачаево-Черкесская Республика
# толокнянка обыкновенная, Липецкая область
# толокнянка обыкновенная, Республика Мордовия
# толокнянка обыкновенная, Московская область
# толокнянка обыкновенная, Пензенская область
# толокнянка обыкновенная, Рязанская область
# толокнянка обыкновенная, Самарская область
# толокнянка обыкновенная, Смоленская область
# толокнянка обыкновенная, Тамбовская область
# толокнянка обыкновенная, Тверская область
# толокнянка обыкновенная, Тульская область
# толокнянка обыкновенная, Ярославская область
# чемерица лобеля, Вологодская область
# чемерица лобеля, Курганская область
# чемерица лобеля, Ленинградская область
# чемерица лобеля, Республика Марий Эл
# чемерица лобеля, Оренбургская область
# чемерица лобеля, Ростовская область
# чемерица лобеля, Смоленская область
# чемерица лобеля, Ярославская область
# черника обыкновенная, Воронежская область
# черника обыкновенная, Кабардино-Балкарская Республика
# черника обыкновенная, Курская область
# черника обыкновенная, Липецкая область
# черника обыкновенная, Самарская область
# черника обыкновенная, Саратовская область
# черника обыкновенная, Тульская область
# шлемник байкальский, Амурская область
# шлемник байкальский, Еврейская автономная область
# шлемник байкальский, Забайкальский край
# шлемник байкальский, Приморский край
# шлемник байкальский, Республика Саха (Якутия)
# шлемник байкальский, Хабаровский край
# щитовник мужской, Республика Бурятия
# щитовник мужской, Иркутская область
# щитовник мужской, Республика Коми
# щитовник мужской, Красноярский край
# щитовник мужской, Курганская область
# щитовник мужской, Оренбургская область
# щитовник мужской, Ростовская область
# щитовник мужской, Саратовская область
# щитовник мужской, Республика Тыва
# щитовник мужской, Тюменская область
