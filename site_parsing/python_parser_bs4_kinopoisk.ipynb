# %% [markdown]
# # Парсер сайтов
# ## Импорты

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import lxml
from time import sleep
# from unicodedata import normalize

# %% [markdown]
# ## Парсинг

# %%
data = []

for page in range(1, 6):
    print(page)
    
    URL = f"https://www.kinopoisk.ru/lists/movies/top250/?page={page}"
    headers = {
        "Accept": "*/*", 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
        }
    req = requests.get(URL, headers = headers)
    # req = requests.get(URL)
    print(req.status_code)
    
    sleep(3)
    
    soup = bs(req.text, "lxml")
    
    films = soup.findAll('div', class_='styles_upper__j8BIs')

    for film in films:
        link = 'https://www.kinopoisk.ru' + film.find('a', class_='base-movie-main-info_link__YwtP1').get('href')
        local_name = film.find('div', class_='base-movie-main-info_mainInfo__ZL_u3').text
        try:
            original_name, year, length = film.find('span', class_='desktop-list-main-info_secondaryText__M_aus').text.replace(u'\xa0', u' ').split(', ')
        except:
            original_name = local_name
        data_group_parse = film.findAll('span', class_='desktop-list-main-info_truncatedText__IMQRP')
        bunch = data_group_parse[0].text.replace(u'\xa0\xa0', u' ').replace(' • ', ' ').split(' ')
        if bunch[0] == 'Новая':
            country = bunch[0] + ' ' + bunch[1]
            film_type = bunch[2]
            director = bunch[4] + ' ' + bunch[5]
        else:
            country = bunch[0]
            film_type = bunch[1]
            director = bunch[3] + ' ' + bunch[4]
        cast = data_group_parse[1].text.replace('В ролях: ', '')
        rate = film.find('span', class_='styles_kinopoiskValue__9qXjg').text
    #     country_bunch = film.findAll('img', class_='countries_flag__5cI2E')
    #     for c in country_bunch:
    #         country = c.get('alt')


        data.append([link, local_name, original_name, year, length, film_type, director, cast, country, rate])
# Out:
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200

# %%
# data = []

html = None

for page in range(1, 6):
    print(page)
    
    URL = f"https://www.kinopoisk.ru/lists/movies/top250/?page={page}"
    headers = {
        "Accept": "*/*", 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
        }
    req = requests.get(URL, headers = headers)
    # req = requests.get(URL)
    print(req.status_code)
    
    soup = bs(req.text, "lxml")
    
#     with open("kinopoisk_top250_page_extraction.html", "a", encoding='utf-8') as file:
#         file.write(req.text)
    
    with open("kinopoisk_top250.html", "a", encoding='utf-8') as file:
        file.write(soup.text)
        
    sleep(3)
    


#     films = soup.findAll('div', class_='styles_upper__j8BIs')

#     for film in films:
#         link = 'https://www.kinopoisk.ru' + film.find('a', class_='base-movie-main-info_link__YwtP1').get('href')
#         local_name = film.find('div', class_='base-movie-main-info_mainInfo__ZL_u3').text
#         try:
#             original_name, year, length = film.find('span', class_='desktop-list-main-info_secondaryText__M_aus').text.replace(u'\xa0', u' ').split(', ')
#         except:
#             original_name = local_name
#         data_group_parse = film.findAll('span', class_='desktop-list-main-info_truncatedText__IMQRP')
#         bunch = data_group_parse[0].text.replace(u'\xa0\xa0', u' ').replace(' • ', ' ').split(' ')
#         if bunch[0] == 'Новая':
#             country = bunch[0] + ' ' + bunch[1]
#             film_type = bunch[2]
#             director = bunch[4] + ' ' + bunch[5]
#         else:
#             country = bunch[0]
#             film_type = bunch[1]
#             director = bunch[3] + ' ' + bunch[4]
#         cast = data_group_parse[1].text.replace('В ролях: ', '')
#         rate = film.find('span', class_='styles_kinopoiskValue__9qXjg').text
#     #     country_bunch = film.findAll('img', class_='countries_flag__5cI2E')
#     #     for c in country_bunch:
#     #         country = c.get('alt')


#         data.append([link, local_name, original_name, year, length, film_type, director, cast, country, rate])
# Out:
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200

# %%
URL = 'https://www.kinopoisk.ru/lists/movies/top250/?page=2'
headers = {
    "Accept": "*/*", 
     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }
req = requests.get(URL, headers = headers)
    # req = requests.get(URL)
print(req.status_code)
 
soup = bs(req.text, "lxml")
print(soup)
# Out:
# 200
# <!DOCTYPE html>
# <html><head><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><title data-tid="57f72b5">250 лучших фильмов — Кинопоиск</title><meta content="#1f1f1f" data-tid="57f72b5" name="theme-color"/><meta content="yes" data-tid="57f72b5" name="apple-mobile-web-app-capable"/><meta content="black" data-tid="57f72b5" name="apple-mobile-web-app-status-bar-style"/><meta content="Кинопоиск" data-tid="57f72b5" name="apple-mobile-web-app-title"/><meta content="app-id=477718890, ct=kp-web, pt=214944, mt=8" data-tid="57f72b5" name="apple-itunes-app"/><meta content="Кинопоиск" data-tid="57f72b5" name="application-name"/><meta content="121953784483000" data-tid="57f72b5" property="fb:app_id"/><meta content="152308956519" data-tid="57f72b5" property="fb:pages"/><meta content="Кинопоиск" data-tid="57f72b5" property="og:site_name"/><meta content="#000" data-tid="57f72b5" name="msapplication-TileColor"/><meta content="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" data-tid="57f72b5" name="msapplication-TileImage"/><meta content="//st.kp.yandex.net/public/xml/ieconfig.xml" data-tid="57f72b5" name="msapplication-config"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-16.svg" rel="mask-icon"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/apple-favicon-152.png" rel="apple-touch-icon-precomposed"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-57.png" rel="icon" sizes="57x57" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-76.png" rel="icon" sizes="76x76" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-96.png" rel="icon" sizes="96x96" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-120.png" rel="icon" sizes="120x120" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" rel="icon" sizes="144x144" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-152.png" rel="icon" sizes="152x152" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-180.png" rel="icon" sizes="180x180" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-196.png" rel="icon" sizes="196x196" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-64.ico" rel="icon"/><link data-tid="57f72b5" href="/kp_search.xml" rel="search" title="Поиск на kinopoisk.ru" type="application/opensearchdescription+xml"/><meta content="Рейтинг составлен по результатам голосования посетителей сайта. Любой желающий может принять в нем участие, проголосовав за свой любимый фильм." data-tid="57f72b5" name="description"/><link data-tid="57f72b5" href="/news.rss" rel="alternate" title="RSS" type="application/rss+xml"/><link data-tid="57f72b5" href="https://www.kinopoisk.ru/lists/movies/top250/" rel="canonical"/><meta content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5" property="og:title"/><meta content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5" property="twitter:title"/><meta content="Рейтинг составлен по результатам г ...
# </script><div data-reactroot="" id="__next"><div class="styles_root__hSE6c styles_promoPopover__QZb7t" data-tid="d504712e"><button class="styles_closeButton__LEexp" type="button"><span class="styles_closeButtonIcon__w69HE"></span></button></div><div class="styles_root__goB3B" data-tid="ef426037"><div class="styles_root__BJH2_ styles_rootWithBranding__T8cIK styles_headerContainer__3KSNh" data-tid="1d1e4a8c"><header class="styles_root__jlo2L styles_header__0LyFn styles_rootDark__nQDyF" data-tid="63b05890" style="--header-height:150px"><div class="styles_root__MPMoz styles_branding__J6rew" data-tid="13a09d50" style="background-color:#000000"><img class="styles_image__FONgM" data-tid="b35288c1" src="https://avatars.mds.yandex.net/get-bunker/135516/ea9cb0f700d008d7432c137c4c089815d81928e3/orig" srcset="https://avatars.mds.yandex.net/get-bunker/135516/ea9cb0f700d008d7432c137c4c089815d81928e3/orig 1x, https://avatars.mds.yandex.net/get-bunker/49769/1ff764ed2c2f92ae8ba60a56ef5e571e8b7d82ef/orig 2x"/><a aria-label="presentation" class="styles_link__nbBFW" href="https://hd.kinopoisk.ru/?utm_source=header&amp;source=kinopoisk_selfprmo_kinopoisk_header" target="_blank"></a></div><div class="header-navigation styles_navigationWithBranding__3A0vW styles_navigation__S8raz styles_navigationDark__x0vdW"><div class="styles_logoContainer__G47EP"><div class="styles_root__jfc_s" data-tid="911e2f4d"><div class=""><button class="styles_root__coHaQ styles_burger__HcbjK" data-tid="8ed90190" type="button"><span class="styles_icon__J3wes" style="color:#DA987A"></span></button><div class="styles_dropdown__MqT__ styles_dropdownOpen__mTn_V styles_dropdownDefault__KwZHT" data-tid="585eb7c0"><div class="styles_dropdownMenu__bouwC styles_dropdownMenu__c7FZ4 styles_dropdownMenuDark__NzGxR"><div class="styles_navigationMenu__c_jLJ styles_root__RBtQR" data-tid="e500879d"><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/128809/4d6f5bd4e839b166859243f82e9fdeb3bc910931/svg"/>Главная</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="https://hd.kinopoisk.ru/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/61205/478c72b68bc4ac507483b2676994bbc1df5f05be/svg"/>Онлайн-кинотеатр</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/lists/categories/movies/1/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/50064/ab24b8099cb4ca11c08b0def91dc5c1d4fd78649/svg"/>Фильмы</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/lists/categories/movies/3/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/61205/9daeaf410906b5794685b7b5bb25dfd2c647fccf/svg"/>Сериалы</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/afisha/new/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/118781/ae7fbfc1773a6bbd61ee0154628c6fe14bf6959e/svg"/>Билеты в кино</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/media/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/118781/960a47a181b1b0a28ceb45a075e64c1a9378442c/svg"/>Медиа</a></div></div></div></div><a class="styles_root__dYidr styles_logo___bcop" data-tid="d4e8d214" href="/"><img alt="Кинопоиск" class="styles_img__3hWmL kinopoisk-header-logo__img" data-tid="79e4350" src="https://avatars.mds.yandex.net/get-bunker/135516/bf934291747932531c687349553804b1410941b4/orig" srcset="https://avatars.mds.yandex.net/get-bunker/135516/bf934291747932531c687349553804b1410941b4/orig 1x, https://avatars.mds.yandex.net/g ...

# %%
with open("kinopoisk_top250_page_extraction.html", "a", encoding='utf-8') as file:
        file.write(req.text)

# %%
with open("kinopoisk_top250_page_extraction.html", encoding='utf-8') as file:
    src = file.read()

# %%
src
# Out:
# '<!DOCTYPE html><html><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title data-tid="57f72b5">250 лучших фильмов — Кинопоиск</title><meta name="theme-color" content="#1f1f1f" data-tid="57f72b5"/><meta name="apple-mobile-web-app-capable" content="yes" data-tid="57f72b5"/><meta name="apple-mobile-web-app-status-bar-style" content="black" data-tid="57f72b5"/><meta name="apple-mobile-web-app-title" content="Кинопоиск" data-tid="57f72b5"/><meta name="apple-itunes-app" content="app-id=477718890, ct=kp-web, pt=214944, mt=8" data-tid="57f72b5"/><meta name="application-name" content="Кинопоиск" data-tid="57f72b5"/><meta property="fb:app_id" content="121953784483000" data-tid="57f72b5"/><meta property="fb:pages" content="152308956519" data-tid="57f72b5"/><meta property="og:site_name" content="Кинопоиск" data-tid="57f72b5"/><meta name="msapplication-TileColor" content="#000" data-tid="57f72b5"/><meta name="msapplication-TileImage" content="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" data-tid="57f72b5"/><meta name="msapplication-config" content="//st.kp.yandex.net/public/xml/ieconfig.xml" data-tid="57f72b5"/><link rel="mask-icon" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-16.svg" data-tid="57f72b5"/><link rel="apple-touch-icon-precomposed" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/apple-favicon-152.png" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-57.png" sizes="57x57" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-76.png" sizes="76x76" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-96.png" sizes="96x96" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-120.png" sizes="120x120" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-128.png" sizes="128x128" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" sizes="144x144" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-152.png" sizes="152x152" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-180.png" sizes="180x180" data-tid="57f72b5"/><link rel="icon" type="image/png" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-196.png" sizes="196x196" data-tid="57f72b5"/><link rel="icon" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-64.ico" data-tid="57f72b5"/><link rel="search" type="application/opensearchdescription+xml" title="Поиск на kinopoisk.ru" href="/kp_search.xml" data-tid="57f72b5"/><meta name="description" content="Рейтинг составлен по результатам голосования посетителей сайта. Любой желающий может принять в нем участие, проголосовав за свой любимый фильм." data-tid="57f72b5"/><link type="application/rss+xml" rel="alternate" title="RSS" href="/news.rss" data-tid="57f72b5"/><link rel="canonical" href="https://www.kinopoisk.ru/lists/movies/top250/" data-tid="57f72b5"/><meta property="og:title" content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5"/><meta property="twitter:title" content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5"/><meta property="og:description" c ...

# %%
soup = bs(src, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><title data-tid="57f72b5">250 лучших фильмов — Кинопоиск</title><meta content="#1f1f1f" data-tid="57f72b5" name="theme-color"/><meta content="yes" data-tid="57f72b5" name="apple-mobile-web-app-capable"/><meta content="black" data-tid="57f72b5" name="apple-mobile-web-app-status-bar-style"/><meta content="Кинопоиск" data-tid="57f72b5" name="apple-mobile-web-app-title"/><meta content="app-id=477718890, ct=kp-web, pt=214944, mt=8" data-tid="57f72b5" name="apple-itunes-app"/><meta content="Кинопоиск" data-tid="57f72b5" name="application-name"/><meta content="121953784483000" data-tid="57f72b5" property="fb:app_id"/><meta content="152308956519" data-tid="57f72b5" property="fb:pages"/><meta content="Кинопоиск" data-tid="57f72b5" property="og:site_name"/><meta content="#000" data-tid="57f72b5" name="msapplication-TileColor"/><meta content="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" data-tid="57f72b5" name="msapplication-TileImage"/><meta content="//st.kp.yandex.net/public/xml/ieconfig.xml" data-tid="57f72b5" name="msapplication-config"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-16.svg" rel="mask-icon"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/apple-favicon-152.png" rel="apple-touch-icon-precomposed"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-57.png" rel="icon" sizes="57x57" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-76.png" rel="icon" sizes="76x76" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-96.png" rel="icon" sizes="96x96" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-120.png" rel="icon" sizes="120x120" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-144.png" rel="icon" sizes="144x144" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-152.png" rel="icon" sizes="152x152" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-180.png" rel="icon" sizes="180x180" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-196.png" rel="icon" sizes="196x196" type="image/png"/><link data-tid="57f72b5" href="https://yastatic.net/s3/kinopoisk-frontend/common-static/img/projector-favicon/favicon-64.ico" rel="icon"/><link data-tid="57f72b5" href="/kp_search.xml" rel="search" title="Поиск на kinopoisk.ru" type="application/opensearchdescription+xml"/><meta content="Рейтинг составлен по результатам голосования посетителей сайта. Любой желающий может принять в нем участие, проголосовав за свой любимый фильм." data-tid="57f72b5" name="description"/><link data-tid="57f72b5" href="/news.rss" rel="alternate" title="RSS" type="application/rss+xml"/><link data-tid="57f72b5" href="https://www.kinopoisk.ru/lists/movies/top250/" rel="canonical"/><meta content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5" property="og:title"/><meta content="250 лучших фильмов — списки лучших фильмов и сериалов — Кинопоиск" data-tid="57f72b5" property="twitter:title"/><meta content="Рейтинг составлен по результатам г ...
# </script><div data-reactroot="" id="__next"><div class="styles_root__hSE6c styles_promoPopover__QZb7t" data-tid="d504712e"><button class="styles_closeButton__LEexp" type="button"><span class="styles_closeButtonIcon__w69HE"></span></button></div><div class="styles_root__goB3B" data-tid="ef426037"><div class="styles_root__BJH2_ styles_rootWithBranding__T8cIK styles_headerContainer__3KSNh" data-tid="1d1e4a8c"><header class="styles_root__jlo2L styles_header__0LyFn styles_rootDark__nQDyF" data-tid="63b05890" style="--header-height:150px"><div class="styles_root__MPMoz styles_branding__J6rew" data-tid="13a09d50" style="background-color:#000000"><img class="styles_image__FONgM" data-tid="b35288c1" src="https://avatars.mds.yandex.net/get-bunker/135516/ea9cb0f700d008d7432c137c4c089815d81928e3/orig" srcset="https://avatars.mds.yandex.net/get-bunker/135516/ea9cb0f700d008d7432c137c4c089815d81928e3/orig 1x, https://avatars.mds.yandex.net/get-bunker/49769/1ff764ed2c2f92ae8ba60a56ef5e571e8b7d82ef/orig 2x"/><a aria-label="presentation" class="styles_link__nbBFW" href="https://hd.kinopoisk.ru/?utm_source=header&amp;source=kinopoisk_selfprmo_kinopoisk_header" target="_blank"></a></div><div class="header-navigation styles_navigationWithBranding__3A0vW styles_navigation__S8raz styles_navigationDark__x0vdW"><div class="styles_logoContainer__G47EP"><div class="styles_root__jfc_s" data-tid="911e2f4d"><div class=""><button class="styles_root__coHaQ styles_burger__HcbjK" data-tid="8ed90190" type="button"><span class="styles_icon__J3wes" style="color:#DA987A"></span></button><div class="styles_dropdown__MqT__ styles_dropdownOpen__mTn_V styles_dropdownDefault__KwZHT" data-tid="585eb7c0"><div class="styles_dropdownMenu__bouwC styles_dropdownMenu__c7FZ4 styles_dropdownMenuDark__NzGxR"><div class="styles_navigationMenu__c_jLJ styles_root__RBtQR" data-tid="e500879d"><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/128809/4d6f5bd4e839b166859243f82e9fdeb3bc910931/svg"/>Главная</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="https://hd.kinopoisk.ru/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/61205/478c72b68bc4ac507483b2676994bbc1df5f05be/svg"/>Онлайн-кинотеатр</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/lists/categories/movies/1/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/50064/ab24b8099cb4ca11c08b0def91dc5c1d4fd78649/svg"/>Фильмы</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/lists/categories/movies/3/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/61205/9daeaf410906b5794685b7b5bb25dfd2c647fccf/svg"/>Сериалы</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/afisha/new/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/118781/ae7fbfc1773a6bbd61ee0154628c6fe14bf6959e/svg"/>Билеты в кино</a><a class="styles_root__7mPJN styles_darkThemeItem__E_aGY" data-tid="de7c6530" href="/media/"><img class="styles_icon__PXEHs" data-tid="b35288c1" loading="lazy" src="https://avatars.mds.yandex.net/get-bunker/118781/960a47a181b1b0a28ceb45a075e64c1a9378442c/svg"/>Медиа</a></div></div></div></div><a class="styles_root__dYidr styles_logo___bcop" data-tid="d4e8d214" href="/"><img alt="Кинопоиск" class="styles_img__3hWmL kinopoisk-header-logo__img" data-tid="79e4350" src="https://avatars.mds.yandex.net/get-bunker/135516/bf934291747932531c687349553804b1410941b4/orig" srcset="https://avatars.mds.yandex.net/get-bunker/135516/bf934291747932531c687349553804b1410941b4/orig 1x, https://avatars.mds.yandex.net/g ...

# %%
data = []
# Out:
# []

# %%
films = soup.findAll('div', class_='styles_upper__j8BIs')


for film in films:
    link = 'https://www.kinopoisk.ru' + film.find('a', class_='base-movie-main-info_link__YwtP1').get('href')
    local_name = film.find('div', class_='base-movie-main-info_mainInfo__ZL_u3').text
    try:
        original_name, year, length = film.find('span', class_='desktop-list-main-info_secondaryText__M_aus').text.replace(u'\xa0', u' ').split(', ')
    except:
        original_name = local_name
    data_group_parse = film.findAll('span', class_='desktop-list-main-info_truncatedText__IMQRP')
    bunch = data_group_parse[0].text.replace(u'\xa0\xa0', u' ').replace(' • ', ' ').split(' ')
    if bunch[0] == 'Новая':
        country = bunch[0] + ' ' + bunch[1]
        film_type = bunch[2]
        director = bunch[4] + ' ' + bunch[5]
    else:
        country = bunch[0]
        film_type = bunch[1]
        director = bunch[3] + ' ' + bunch[4]
    cast = data_group_parse[1].text.replace('В ролях: ', '')
    rate = film.find('span', class_='styles_kinopoiskValue__9qXjg').text
#     country_bunch = film.findAll('img', class_='countries_flag__5cI2E')
#     for c in country_bunch:
#         country = c.get('alt')


    data.append([link, local_name, original_name, year, length, film_type, director, cast, country, rate])

# %%
len(data)
# Out:
# 100

# %%
# cvb = soup.findAll('img', class_='countries_flag__5cI2E')

# df = []

# for cn in cvb:
#     cn.get('alt')
#     df.append([cn])
    
# df

# cvb

# %% [markdown]
# ## Сохранение результата
